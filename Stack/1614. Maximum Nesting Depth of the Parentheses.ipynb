# %%
s = "(1+(2*3)+((8)/4))+1"

# %%
s = "(1)+((2))+(((3)))"

# %%
ans = 0
cnt = 0

for i in s:
    if i=="(":
        cnt+=1
        ans = max(ans, cnt)
    elif i==')':
        cnt-=1
print(ans)
# Out:
# 3

# %% [markdown]
# ![image.png](attachment:image.png)
